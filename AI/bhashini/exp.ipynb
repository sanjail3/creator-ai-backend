# %%
from pipeline import Pipeline,ConfigPipeline

# %%
from utils import Operation,Language,pipelineId

# %%
config = ConfigPipeline()
config.config(operation= Operation.tts,sourceLanguage= Language.english,pipeline_id= pipelineId.MeitY,targetLanguage= Language.hindi)
pipeline = Pipeline(config)
res = pipeline.execute(text="Hello World")
# Out:
# en
# {'pipelineResponse': [{'taskType': 'tts', 'config': {'audioFormat': 'wav', 'language': {'sourceLanguage': 'en', 'sourceScriptCode': ''}, 'encoding': 'base64', 'samplingRate': 22050}, 'output': None, 'audio': [{'audioContent': '...', 'audioUri': None}]}]}

# %%
f = open("C:\\Users\\ragut\\AppData\\Local\\Temp\\audio7d1u5i6t.wav","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 f = open("C:\\Users\\ragut\\AppData\\Local\\Temp\\audio7d1u5i6t.wav","r")
#
# File h:\creator-ai-backend\.venv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\ragut\\AppData\\Local\\Temp\\audio7d1u5i6t.wav'

# %%
import tempfile
f = tempfile.mkdtemp()

# %%
audio_path = f"{f}/audio.wav"
